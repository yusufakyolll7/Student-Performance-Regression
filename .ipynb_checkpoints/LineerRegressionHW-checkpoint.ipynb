# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Student_Performance.csv")

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
sns.pairplot(df)
plt.show()

# %%
df["Extracurricular Activities"] = df["Extracurricular Activities"].map({"No": 0, "Yes": 1})

# %%
print(df["Extracurricular Activities"].value_counts())
# Out:
# Extracurricular Activities
# 0    5052
# 1    4948
# Name: count, dtype: int64

# %%
print(df.dtypes["Extracurricular Activities"])
# Out:
# int64

# %%
sns.pairplot(df)
plt.show()

# %%
df.corr()
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.012390
# Previous Scores                       -0.012390         1.000000
# Extracurricular Activities             0.003873         0.008369
# Sleep Hours                            0.001245         0.005944
# Sample Question Papers Practiced       0.017463         0.007888
# Performance Index                      0.373730         0.915189
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.003873     0.001245
# Previous Scores                                     0.008369     0.005944
# Extracurricular Activities                          1.000000    -0.023284
# Sleep Hours                                        -0.023284     1.000000
# Sample Question Papers Practiced                    0.013103     0.003990
# ...

# %%
sns.regplot(x=df['Performance Index'],y=df['Previous Scores'])
plt.show()

# %%
sns.regplot(x=df['Performance Index'],y=df['Hours Studied'])
plt.show()

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
y.head()
# Out:
# 0    91.0
# 1    65.0
# 2    45.0
# 3    36.0
# 4    66.0
# Name: Performance Index, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.7725075 , -0.13738686, -0.98965352,  0.85938628, -1.62071899],
#        [-0.77291962,  0.67136016, -0.98965352,  0.85938628,  1.19474004],
#        [ 0.7725075 ,  1.19126896, -0.98965352,  1.4517941 ,  1.19474004],
#        ...,
#        [-0.77291962,  1.30680425, -0.98965352, -1.51024501, -0.21298947],
#        [ 1.54522106, -0.13738686,  1.01045465, -0.91783718,  0.84280766],
#        [ 1.54522106, -0.88836624, -0.98965352,  0.85938628, -0.91685423]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(X_test)

# %%
y_pred
# Out:
# array([47.91552042, 43.88285858, 79.56192857, ..., 71.99013192,
#        69.52691248, 36.87960449])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
mse=mean_squared_error(y_test,y_pred)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("mse: ", mse)
print("mae: ", mae)
print("r2score: ",score)
# Out:
# mse:  4.256407547565786
# mae:  1.6341484613506647
# r2score:  0.9886098260837627

# %%
plt.scatter(y_test,y_pred)
plt.show()

# %%
X.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
X_test[0]
# Out:
# array([ 0.38615072, -0.65729566,  1.01045465,  0.85938628,  0.84280766])

# %%
df.iloc[0]
# Out:
# Hours Studied                        7.0
# Previous Scores                     99.0
# Extracurricular Activities           1.0
# Sleep Hours                          9.0
# Sample Question Papers Practiced     1.0
# Performance Index                   91.0
# Name: 0, dtype: float64

# %%
new_student = [[5, 80, 1, 6, 3,]]

# %%
new_student_scaled = scaler.transform(new_student)
# Out:
# C:\Users\Monster\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
predicted_score = regression.predict(new_student_scaled)

# %%
predicted_score
# Out:
# array([65.69925126])

# %%
students = [
    [6, 86, 0, 5, 2],
    [3, 69, 1, 8, 1],
    [4, 75, 0, 10, 0]
]

# %%
predicted_scores = regression.predict(scaler.transform(students))
print(predicted_scores)
# Out:
# [73.38220185 49.38698985 58.53515491]
# C:\Users\Monster\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
